# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260427/blob/main/tibame20260525.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req
import bs4 as bs

url = "https://tabelog.com/tw/tokyo/rstLst/sweets/?SrtT=rt"
resp = req.urlopen(url)
content = resp.read()
html = bs.BeautifulSoup(content)
# html.find("a", {"class":"list-rst__rst-name-target"})
rs = html.find_all("div", {"class":"list-rst__body"})
for r in rs:
    # 地點類型/評分/晚價格/午價格/例假日/圖片的src
    name = r.find("a", {"class":"list-rst__rst-name-target"})
    area_genre = r.find("div", {"class":"list-rst__area-genre"})
    rating = r.find("span", {"class":"c-rating__val"})
    prices = r.find_all("span", {"class":"c-rating-v3__val"})
    dinner_price = prices[0]
    lunch_price = prices[1]
    holiday = r.find("span", {"class":"list-rst__holiday-text"})
    imgs = r.find_all("img", {"class":"js-thumbnail-img"})

    name_text = name.get_text().strip()
    name_href = name["href"]
    area_genre_text = area_genre.get_text().strip()
    rating_text = rating.get_text().strip()
    dinner_price_text = dinner_price.get_text().strip()
    lunch_price_text = lunch_price.get_text().strip()
    holiday_text = holiday.get_text().strip()

    # 拿出img裡所有的src, 放置到一個list裡
    imgs_src = []
    for img in imgs:
        imgs_src.append(img["src"])

    # imgs_src = [img["src"] for img in imgs]

    print(rating_text)
    print(name_text)
    print(name_href)
    print(area_genre_text)
    print(dinner_price_text)
    print(lunch_price_text)
    print(holiday_text)
    print(imgs_src)
    print("-" * 30)
# Out:
# 4.24
# Bon.nu
# https://tabelog.com/tw/tokyo/A1304/A130401/13184186/
# 參宮橋車站 356m / 法式料理, 牛排, 蛋糕
# JPY 50,000 - JPY 59,999
# JPY 50,000 - JPY 59,999
# -
# ['...', '...', '...']
# ------------------------------
# 4.20
# Okashiya Ucchi
# https://tabelog.com/tw/tokyo/A1309/A130901/13238644/
# 北參道車站 250m / 蛋糕, 西式甜點
# -
# JPY 5,000 - JPY 5,999
# 星期一
# ['...', '...', '...']
# ------------------------------
# 4.16
# 蒼菓
# https://tabelog.com/tw/tokyo/A1307/A130703/13297330/
# 廣尾車站 702m / 甜食
# JPY 15,000 - JPY 19,999
# JPY 15,000 - JPY 19,999
# 星期一, 星期二, 星期日
# ['...', '...', '...']
# ------------------------------
# 4.15
# Yama
# https://tabelog.com/tw/tokyo/A1316/A131602/13279936/
# 白金台車站 725m / 甜食
# JPY 20,000 - JPY 29,999
# JPY 30,000 - JPY 39,999
# 星期二, 星期三
# ['...', '...', '...']
# ------------------------------
# 3.98
# ESPRIT C. KEI GINZA
# https://tabelog.com/tw/tokyo/A1301/A130101/13296199/
# 銀座車站 330m / 法式料理, 甜食
# JPY 30,000 - JPY 39,999
# -
# 星期一, 星期日
# ['...', '...', '...']
# ------------------------------
# 3.97
# GELATERIA ACQUOLINA
# https://tabelog.com/tw/tokyo/A1317/A131701/13141364/
# 祐天寺車站 45m / 意式冰淇淋/冰淇淋, 軟冰淇淋
# -
# - JPY 999
# 星期一, 星期二
# ['...', '...', '...']
# ------------------------------
# 3.89
# Patisserie Ryoko
# https://tabelog.com/tw/tokyo/A1316/A131603/13137010/
# 高輪台車站 423m / 蛋糕, 泡芙, 西式甜點
# -
# - JPY 999
# 星期一, 星期二, 星期三, 星期四
# ['...', '...', '...']
# ------------------------------
# 3.88
# a tes souhaits!
# https://tabelog.com/tw/tokyo/A1320/A132001/13005853/
# 西荻窪車站 992m / 蛋糕, 甜食
# - JPY 999
# - JPY 999
# 星期一, 星期二
# ['...', '...', '...']
# ------------------------------
# 3.88
# AIGRE DOUCE
# https://tabelog.com/tw/tokyo/A1305/A130502/13005641/
# 目白車站 562m / 蛋糕, 馬卡龍
# JPY 1,000 - JPY 1,999
# JPY 1,000 - JPY 1,999
# 星期一, 星期二
# ['...', '...', '...']
# ------------------------------
# 3.88
# Frederic Cassel 銀座三越店
# https://tabelog.com/tw/tokyo/A1301/A130101/13116839/
# 銀座車站 176m / 蛋糕, 甜食, 巧克力
# -
# JPY 2,000 - JPY 2,999
# -
# ['...', '...', '...']
# ------------------------------
# 3.87
# patisserie Paris S'eveille
# https://tabelog.com/tw/tokyo/A1317/A131703/13005198/
# 自由丘車站 212m / 蛋糕, 咖啡店, 麵包
# JPY 1,000 - JPY 1,999
# JPY 1,000 - JPY 1,999
# -
# ['...', '...', '...']
# ------------------------------
# 3.87
# Think
# https://tabelog.com/tw/tokyo/A1311/A131105/13283557/
# 鶯谷車站 643m / 麵包, 西式甜點
# JPY 1,000 - JPY 1,999
# -
# 星期一, 星期二
# ['...', '...', '...']
# ------------------------------
# 3.87
# Laekker
# https://tabelog.com/tw/tokyo/A1303/A130303/13243988/
# 代官山車站 379m / 麵包, 西式甜點
# - JPY 999
# - JPY 999
# -
# ['...', '...', '...']
# ------------------------------
# 3.86
# CHOCOLATIER PALET D’OR 東京
# https://tabelog.com/tw/tokyo/A1302/A130201/13038473/
# 二重橋前車站 351m / 巧克力, 咖啡店, 蛋糕
# JPY 2,000 - JPY 2,999
# JPY 2,000 - JPY 2,999
# -
# ['...', '...', '...']
# ------------------------------
# 3.86
# Avranches Guesnay
# https://tabelog.com/tw/tokyo/A1310/A131004/13186450/
# 春日車站 30m / 蛋糕, 巧克力
# JPY 1,000 - JPY 1,999
# JPY 1,000 - JPY 1,999
# 星期一, 星期二
# ['...', '...', '...']
# ------------------------------
# 3.86
# Boulangerie Sudo
# https://tabelog.com/tw/tokyo/A1317/A131709/13098861/
# 松陰神社前車站 34m / 麵包, 咖啡店, 甜食
# - JPY 999
# - JPY 999
# 星期一, 星期二, 星期三, 星期四
# ['...', '...', '...']
# ------------------------------
# 3.86
# Ryoura
# https://tabelog.com/tw/tokyo/A1317/A131707/13188208/
# 用賀車站 290m / 蛋糕, 西式甜點
# JPY 3,000 - JPY 3,999
# -
# 星期二, 星期三
# ['...', '...', '...']
# ------------------------------
# 3.86
# 一幸庵
# https://tabelog.com/tw/tokyo/A1323/A132302/13005076/
# 茗荷谷車站 207m / 日式點心
# -
# - JPY 999
# 星期一, 星期二, 星期日
# ['...', '...', '...']
# ------------------------------
# 3.85
# VIRON 丸之內店
# https://tabelog.com/tw/tokyo/A1302/A130201/13043904/
# 東京車站 320m / 麵包, 蛋糕, 咖啡店
# JPY 1,000 - JPY 1,999
# JPY 1,000 - JPY 1,999
# -
# ['...', '...', '...']
# ------------------------------
# 3.85
# 日本橋 長門
# https://tabelog.com/tw/tokyo/A1302/A130202/13011481/
# 日本橋車站 292m / 日式點心
# JPY 1,000 - JPY 1,999
# JPY 1,000 - JPY 1,999
# 星期日, 節假日
# ['...', '...', '...']
# ------------------------------

# %%
"       \t   \n   a   bc    \n     ".strip()
# Out:
# 'a   bc'

# %% [markdown]
# ```
# CSS語法: 找到HTML區塊 加上排版
#
# 1. 透過HTML名字:
#
# a{
#     background-color:blue
# }
#
# 為了讓CSS語法可以去訂為某些特定區塊, 所以我們會為這些區塊加入可辨識屬性
# class="分類1 分類2"
# 2. 透過class做選擇
#
# .class名字{
#     排版規則
# }
#
# .js-thumbnail-img{
#     border-radius:50%
# }
#
# ```

# %% [markdown]
# ```
# 1. 前端: 讓使用者可以看到回覆(HTML)
# a. HTML: 內容
# b. CSS: 排版(O)
# c. JavaScript: 動態(X)
#
# 我們先不考慮動態(JavaScript)的部分的原因
# a. 根本沒有靜態動態之分: 網路世界只有網址和答案
# b. JavaScript會牽扯到的是"網址從本地端觸發"(care網址到底是什麼而已)或者是"網址某些部分的做成"(真的要去解析的話工程量太大, 大部分情況建議你換方式)
#
#
# 2. 後端(伺服器端): 處理問題(網址), 丟回回復
# a. 接收網址
# b. 程式處理網址(Flask, Django, FastAPI)
# c. 雜項: 詢問資料庫...
# d. 回覆網址(JSON/HTML/MP4...)
#
# ```
