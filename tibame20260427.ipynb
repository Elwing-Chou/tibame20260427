# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260427/blob/main/tibame20260427.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. colab是一個線上版本的Jupyter notebook(python工具), 副檔名會是.ipynb
#
# 2. 之前我們學的是標準python程式, 副檔名是.py
#
# 3. colab筆記使用的是markdown語法
#
# 4. colab支援latex math語法來幫助你寫數學式子: a. 特殊符號以\開始 b. ()以{}替代
#
# $ 標準差 = \sqrt{\frac{1}{n}({x_{i}-\mu})^{2}} $

# %%
a = 3
print(a)
# Out:
# 3

# %% [markdown]
# 1. LAB1: 從20241001(4499x4499)往後數出n個完全平方日
#
# 2. 想法1. 20241001(開根號是否為整) 20241002 20241003 ....
#
# 3. 想法2. 4499x4499(是否為日期) 4500x4500 4501x4501 ...
#
# 4. 效率比較好? 下一個20720704(4552x4552)
#
# 5. 想法1. 48年x365=17520(個單位)找到下一個
#
# 6. 想法2. 4552-4499=53(個單位)找到下一個
#
# 7. 還沒開始前: 想法2可能要比想法1快上百倍
#
# 8. 演算法就只是想法
